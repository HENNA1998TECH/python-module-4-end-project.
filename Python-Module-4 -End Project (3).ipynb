# %% [markdown]
# ## Module 4 -Python End Project

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %% [markdown]
# #### Preprocessing steps

# %%
import numpy as np
import pandas as pd

#  Acquire the dataset
data = pd.read_excel('ABC companyDataset.xlsx')

data
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %% [markdown]
#  1.Correct the data in the "height" column by replacing it with random numbers between 150 and 180.
# Ensure data consistency and integrity before proceeding with analysis

# %%
data['Height']=np.random.randint(150,181,size=len(data))
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     175     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     165     235
# 2     John Holland  Boston Celtics      30       SG   27     159     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     174     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     173     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     180     203
# 454      Raul Neto       Utah Jazz      25       PG   24     159     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     161     256
# 456    Jeff Withey       Utah Jazz      24        C   26     150     231
# 457       Priyanka       Utah Jazz      34        C   25     160     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### Analysis Tasks
#
# #### 1.. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

# %%
#count the no of the employees in each team

team_distribution = data['Team'].value_counts()
team_distribution
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
# calculate the percentage of split for each team 

percentage_split = (team_distribution/len(data))*100
percentage_split
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %% [markdown]
# ### 2.. Segregate employees based on their positions within the company.

# %%
employees = data.groupby('Position')['Name'].apply(list)
for Position, Names in employees.items():
    print(f"\tEmployees in Position: {Position}")
    for i in Names:
        print(i)
        print("\n")
# Out:
# 	Employees in Position: C
# Kelly Olynyk
#
#
# Jared Sullinger
#
#
# Tyler Zeller
#
#
# Brook Lopez
#
#
# Henry Sims
#
#
# Robin Lopez
#
#
# Kevin Seraphin
#
#
# Joel Embiid
#
#
# Jahlil Okafor
#
#
# Bismack Biyombo
#
#
# Lucas Nogueira
#
#
# Jonas Valanciunas
#
#
# Andrew Bogut
#
#
# Festus Ezeli
#
#
# Marreese Speights
#
#
# Cole Aldrich
#
#
# DeAndre Jordan
#
#
# Tarik Black
#
#
# Roy Hibbert
#
#
# Robert Sacre
#
#
# Tyson Chandler
#
#
# Alex Len
#
#
# Alan Williams
#
#
# Willie Cauley-Stein
#
#
# DeMarcus Cousins
#
#
# Kosta Koufos
#
#
# Pau Gasol
#
#
# Joakim Noah
#
#
# Sasha Kaun
#
#
# Timofey Mozgov
#
#
# Tristan Thompson
#
#
# Joel Anthony
#
#
# Aron Baynes
#
#
# Andre Drummond
#
#
# Jordan Hill
#
#
# Ian Mahinmi
#
#
# Greg Monroe
#
#
# Miles Plumlee
#
#
# JaVale McGee
#
#
# Salah Mejri
#
#
# Zaza Pachulia
#
#
# Dwight Howard
#
#
# Josh Smith
#
#
# Marc Gasol
#
#
# Alexis Ajinca
#
#
# Omer Asik
#
#
# Kendrick Perkins
#
#
# Matt Bonner
#
#
# Boris Diaw
#
#
# Tim Duncan
#
#
# ...

# %% [markdown]
# ### 3. Identify the predominant age group among employees.

# %%
# Define age bins labels for grouping
age_bins = [20,30,40,50,60]
age_labels = ['20-30','31-40','41-50','51-60']

#Create a new column Age group based on the defined bins
data['Age Group'] = pd.cut(data['Age'], bins=age_bins, labels=age_labels)

# Count the number of employees in each group
age_group_counts = data['Age Group'].value_counts()

# Find the most predominant age group
predominant_group = age_group_counts.idxmax()

# Output of the of result
print("Age Group Counts:\n",age_group_counts)
print("\nMost Predominant Age Group:",predominant_group)
# Out:
# Age Group Counts:
#  Age Group
# 20-30    346
# 31-40     91
# 41-50      0
# 51-60      0
# Name: count, dtype: int64
#
# Most Predominant Age Group: 20-30

# %% [markdown]
# ### 4. Discover which team and position have the highest salary expenditure.

# %%
# Group by 'Team' 'Position' and sum of salaries

salary_expenditure = data.groupby(['Team','Position'])['Salary'].sum()

#Find the maximum salary expenditure and corresponding team and position
max_expenditure = salary_expenditure.idxmax()
highest_salary = salary_expenditure.max()

#output result
print(f"The team and position with the highest salary expenditure is :{max_expenditure[0]}team and {max_expenditure[1]} position with a total salary expenditure of{highest_salary}.")
# Out:
# The team and position with the highest salary expenditure is :Los Angeles Lakersteam and SF position with a total salary expenditure of31866445.0.

# %% [markdown]
# ### 5..Investigate if there's any correlation between age and salary, and represent it visually.

# %%
# calculate the correlation coefficient between age and salary 
correlation = data['Age'].corr(data['Salary'])

#output of correlation
print("The correlation between Age and Salary:",correlation)
# Out:
# The correlation between Age and Salary: 0.21400941226570974

# %% [markdown]
# ## Graphical Representation

# %% [markdown]
# ### 1.Distribution of employees across each team

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Bar Plot

# %%
# Count the number of employees in each team
team_distribution = data['Team'].value_counts()

#to create a BarPlot
plt.figure(figsize = (10,6))
sns.barplot(x=team_distribution.index, y=team_distribution.values,color='g',width=0.5,edgecolor='black',)
plt.title('Employees Distribution by Team',fontdict={'fontname':'Comic Sans MS','fontsize':20,'color':'g'})
plt.xlabel('Team')
plt.ylabel('Number of Employees')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 2.Distribution of employees by position
#
#
# ## Pie Chart

# %%
# Count the no of the employees in each position
position_distribution = data['Position'].value_counts()

#to create a piechart
plt.figure(figsize=(10,6))
position_distribution.plot(kind='pie',autopct='%1.1f%%',colors=sns.color_palette('Set2',len(position_distribution)),startangle=90)
plt.title('Employees Distribution by Position',fontdict={'fontname':'Comic Sans MS','fontsize':20,'color':'m'})
plt.show()

# %% [markdown]
# ### 3. Age group among employees
#
# ## Histogram Plot

# %%
# to Create Histogram plot
plt.figure(figsize=(10,6))
plt.hist(data['Age'],bins=np.arange(20,60,10),edgecolor='black')
plt.title('Age Group among Employees',fontdict={'fontname':'Comic Sans Ms','fontsize':20,'color':'c'})
plt.xlabel('Age Group')
plt.ylabel('Number of Employee')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 4.Salary expenditure by team and position
#
# ## Bar Plot

# %%
# salary by team and position
team_position_salary = data.groupby(['Team','Position'])['Salary'].mean().reset_index()

#to create bar chart for salary expenditure by team and position
plt.figure(figsize=(10,6))
plt.bar(team_position_salary['Team']+'-'+team_position_salary['Position'],team_position_salary['Salary'])
plt.title('Highest Salary by Team and Position',fontdict={'fontname':'Comic Sans MS','fontsize':12,'color':'c'})
plt.xlabel('Team Position')
plt.ylabel('Average Salary')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 5. Correlation between Age and Salary
#
# ## Scatter Plot

# %%
#Scatter plot for Age and Salary
plt.figure(figsize=(10,6))
sns.scatterplot(x='Age', y='Salary', data= data, color='green',edgecolor='black')
plt.ylabel("Salary")
plt.xlabel("Age")
plt.title("Correlation between Age and Salary",fontdict={'fontname':'Comic Sans MS','fontsize':20,'color':'r'})
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Story

# %%
print(data.dtypes)
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height        int32
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
# ### Correlation within the Dataset
#
# ## Heat Map

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
data_numeric = data.select_dtypes(include=['number'])

# Drop rows with NaN values 
data_cleaned = data_numeric.dropna()

# Calculate the correlation matrix
correlation_matrix = data_cleaned.corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', linewidths=0.5)
plt.title('Correlation Matrix ', fontsize=16)
plt.show()

# %% [markdown]
# In this ABC company dataset there are 4 categorical columns and 5 numerical columns. Our analysis revealed that-
#
# we can found that the percentage split relative to total no of employees across each team and understood that 'New Orleans Pelicans' team boasts the largest roster, with the greatest number of employees.
# The employee distribution by position graph shows that the SG position as the largest, with the highest number of employees compared to other positions.
# Our analysis shows that the majority of employees fall within the 20-30 age range,making it the dominant age group.
# The data indicates that the 'Los Angeles Lakers'team and SF position account for the largest salary expenditure, representing the greatest financial investment.
# The correlation analysis shows that age and salary are positively related,with a correlation coefficient of 0.2140, indicating that salary increases with age.
